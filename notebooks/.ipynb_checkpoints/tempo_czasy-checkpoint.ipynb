# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import datetime

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(11,7)})

#const
path = os.path.join('..', 'data')
cols = ['Date', 'Time']

# %% [markdown]
# ### Data cleaning

# %%
men_marathon = pd.read_csv(os.path.join(path, 'Men marathon.csv'))
men10km = pd.read_csv(os.path.join(path, 'Men 10km.csv'))
men100m = pd.read_csv(os.path.join(path, 'Men 100m.csv'))
men400m = pd.read_csv(os.path.join(path, 'Men 400m.csv'))

women_marathon = pd.read_csv(os.path.join(path, 'Women marathon.csv'))
women10km = pd.read_csv(os.path.join(path, 'Women 10km.csv'))
women100m = pd.read_csv(os.path.join(path, 'Women 100m.csv'))
women400m = pd.read_csv(os.path.join(path, 'Women 400m.csv'))

women_outdoor = pd.read_csv(os.path.join(path, 'Women outdoor.csv'))
men_outdoor = pd.read_csv(os.path.join(path, 'Men outdoor.csv'))

# %%
men_outdoor
# Out:
#              Competitor Country                 Date  \
# 0         Aries MERRITT     USA  2012-09-07 00:00:00
# 1      Armand DUPLANTIS     SWE  2022-07-24 00:00:00
# 2      Armand DUPLANTIS     SWE  2023-02-25 00:00:00
# 3        Berihu AREGAWI     ETH  2021-12-31 00:00:00
# 4       Bernardo SEGURA     MEX  1994-05-07 00:00:00
# 5          CJ ALBERTSON     USA  2022-10-08 00:00:00
# 6          Daniel KOMEN     KEN  1996-09-01 00:00:00
# 7         David RUDISHA     KEN  2012-08-09 00:00:00
# 8        Eliud KIPCHOGE     KEN  2022-09-25 00:00:00
# 9    Hicham EL GUERROUJ     MAR  1998-07-14 00:00:00
# 10   Hicham EL GUERROUJ     MAR  1999-07-07 00:00:00
# 11   Hicham EL GUERROUJ     MAR  1999-09-07 00:00:00
# 12        Jacob KIPLIMO     UGA  2021-11-21 00:00:00
# 13              Jamaica     JAM  2012-08-11 00:00:00
# 14              Jamaica     JAM  2014-05-24 00:00:00
# 15          Jan ŽELEZNÝ     CZE  1996-05-25 00:00:00
# 16     Javier SOTOMAYOR     CUB  1993-07-27 00:00:00
# 17     Jonathan EDWARDS     GBR  1995-08-07 00:00:00
# 18     Joshua CHEPTEGEI     UGA  2020-08-14 00:00:00
# 19     Joshua CHEPTEGEI     UGA  2020-10-07 00:00:00
# 20        Jürgen SCHULT     GDR  1986-06-06 00:00:00
# 21      Karsten WARHOLM     NOR  2021-08-03 00:00:00
# 22                Kenya     KEN  2005-11-23 00:00:00
# 23                Kenya     KEN  2006-08-25 00:00:00
# 24                Kenya     KEN  2014-05-25 00:00:00
# 25          Kevin MAYER     FRA  2018-09-16 00:00:00
# 26    Maurizio DAMILANO     ITA  1992-10-03 00:00:00
# 27          Mike POWELL     USA  1991-08-30 00:00:00
# 28             Mo FARAH     GBR  2020-09-04 00:00:00
# 29           Nao KAZAMI     JPN  2018-06-24 00:00:00
# 30           Noah NGENY     KEN  1999-09-05 00:00:00
# 31       Rhonex KIPRUTO     KEN  2020-01-12 00:00:00
# 32         Ryan CROUSER     USA  2021-06-18 00:00:00
# 33         Ryan CROUSER     USA  2023-02-18 00:00:00
# 34  Saif Saaeed SHAHEEN     QAT  2004-09-03 00:00:00
# 35       Stephen MOKOKA     RSA  2022-03-06 00:00:00
# 36        United States     USA  1993-08-22 00:00:00
# 37        United States     USA  2015-05-03 00:00:00
# 38           Usain BOLT     JAM  2009-08-16 00:00:00
# 39           Usain BOLT     JAM  2009-08-20 00:00:00
# 40    Wayde VAN NIEKERK     RSA  2016-08-14 00:00:00
# 41         Yohann DINIZ     FRA  2011-03-12 00:00:00
# 42         Yohann DINIZ     FRA  2014-08-15 00:00:00
# 43         Yuriy SEDYKH     URS  1986-08-30 00:00:00
# 44        Yusuke SUZUKI     JPN  2015-03-15 00:00:00
#
#                   Discipline                  DOB          Perf  Progression  \
# 0         110 Metres Hurdles  1985-07-24 00:00:00         12.80          NaN
# 1                 Pole Vault  1999-11-10 00:00:00          6.21          NaN
# 2                 Pole Vault  1999-11-10 00:00:00   6.22   *(i)          NaN
# 3               5 Kilometres  2001-02-28 00:00:00         12:49          NaN
# 4    20,000 Metres Race Walk  1970-02-11 00:00:00    1:17:25.6h          NaN
# 5              50 Kilometres  1993-10-11 00:00:00   2:38:43   *          NaN
# 6                3000 Metres  1976-05-17 00:00:00       7:20.67          NaN
# 7                 800 Metres  1988-12-17 00:00:00       1:40.91          NaN
# 8                   Marathon  1984-11-05 00:00:00       2:01:09          NaN
# 9                1500 Metres  1974-09-14 00:00:00       3:26.00          NaN
# 10                  One Mile  1974-09-14 00:00:00       3:43.13          NaN
# 11               2000 Metres  1974-09-14 00:00:00       4:44.79          NaN
# 12             Half Marathon  2000-11-14 00:00:00         57:31          NaN
# 13        4x100 Metres Relay                  NaN         36.84          NaN
# 14        4x200 Metres Relay                  NaN       1:18.63          NaN
# 15             Javelin Throw  1966-06-16 00:00:00         98.48          NaN
# 16                 High Jump  1967-10-13 00:00:00          2.45          NaN
# 17               Triple Jump  1966-05-10 00:00:00         18.29          NaN
# 18               5000 Metres  1996-09-12 00:00:00      12:35.36          NaN
# 19             10,000 Metres  1996-09-12 00:00:00      26:11.00          NaN
# 20              Discus Throw  1960-05-11 00:00:00         74.08          NaN
# 21        400 Metres Hurdles  1996-02-28 00:00:00         45.94          NaN
# 22                Road Relay                  NaN       1:57:06          NaN
# 23        4x800 Metres Relay                  NaN       7:02.43          NaN
# 24       4x1500 Metres Relay                  NaN      14:22.22          NaN
# 25                 Decathlon  1992-02-10 00:00:00          9126          NaN
# 26   30,000 Metres Race Walk  1957-04-06 00:00:00    2:01:44.1h          NaN
# 27                 Long Jump  1963-11-10 00:00:00          8.95          NaN
# 28                  One Hour  1983-03-23 00:00:00         21330          NaN
# 29            100 Kilometres  1983-04-09 00:00:00       6:09:14          NaN
# 30               1000 Metres  1978-11-02 00:00:00       2:11.96          NaN
# 31             10 Kilometres  1999-10-12 00:00:00         26:24          NaN
# 32                  Shot Put  1992-12-18 00:00:00         23.37          NaN
# 33                  Shot Put  1992-12-18 00:00:00  23.38   *(i)          NaN
# 34  3000 Metres Steeplechase  1982-10-15 00:00:00       7:53.63          NaN
# 35             50 Kilometres  1985-01-31 00:00:00       2:40:13          NaN
# 36        4x400 Metres Relay                  NaN       2:54.29          NaN
# 37     Distance Medley Relay                  NaN       9:15.50          NaN
# 38                100 Metres  1986-08-21 00:00:00          9.58          NaN
# 39                200 Metres  1986-08-21 00:00:00         19.19          NaN
# 40                400 Metres  1992-07-15 00:00:00         43.03          NaN
# 41   50,000 Metres Race Walk  1978-01-01 00:00:00    3:35:27.2h          NaN
# 42   50 Kilometres Race Walk  1978-01-01 00:00:00       3:32:33          NaN
# 43              Hammer Throw  1955-06-11 00:00:00         86.74          NaN
# 44   20 Kilometres Race Walk  1988-01-02 00:00:00       1:16:36          NaN
#
#                                              Venue   Wind
# 0                Boudewijnstadion, Bruxelles (BEL)  '+0.3
# 1                  Hayward Field, Eugene, OR (USA)    NaN
# 2        Maison des Sports, Clermont-Ferrand (FRA)    NaN
# 3                                  Barcelona (ESP)    NaN
# 4                                       Fana (NOR)    NaN
# 5                          San Francisco, CA (USA)    NaN
# 6                                      Rieti (ITA)    NaN
# 7                    Olympic Stadium, London (GBR)    NaN
# 8                                     Berlin (GER)    NaN
# 9                      Stadio Olimpico, Roma (ITA)    NaN
# 10                     Stadio Olimpico, Roma (ITA)    NaN
# 11                    Olympiastadion, Berlin (GER)    NaN
# 12                                    Lisboa (POR)    NaN
# 13                   Olympic Stadium, London (GBR)    NaN
# 14               T. Robinson Stadium, Nassau (BAH)    NaN
# 15                                      Jena (GER)    NaN
# 16                                 Salamanca (ESP)    NaN
# 17                  Ullevi Stadium, Göteborg (SWE)  '+1.3
# 18                    Stade Louis II, Monaco (MON)    NaN
# 19  Estadio de Atletismo del Turia, Valencia (ESP)    NaN
# 20                            Neubrandenburg (GDR)    NaN
# 21                   National Stadium, Tokyo (JPN)    NaN
# 22                                     Chiba (JPN)    NaN
# 23               Boudewijnstadion, Bruxelles (BEL)    NaN
# 24               T. Robinson Stadium, Nassau (BAH)    NaN
# 25        Stade Pierre Paul Bernard, Talence (FRA)    NaN
# 26                                     Cuneo (ITA)    NaN
# 27                   National Stadium, Tokyo (JPN)  '+0.3
# 28               Boudewijnstadion, Bruxelles (BEL)    NaN
# 29                               Lake Saroma (JPN)    NaN
# 30                                     Rieti (ITA)    NaN
# 31                                  Valencia (ESP)    NaN
# 32                 Hayward Field, Eugene, OR (USA)    NaN
# 33                 Holt Arena, Pocatello, ID (USA)    NaN
# 34               Boudewijnstadion, Bruxelles (BEL)    NaN
# 35                                  Gqeberha (RSA)    NaN
# 36       Gottlieb-Daimler Stadion, Stuttgart (GER)    NaN
# 37               T. Robinson Stadium, Nassau (BAH)    NaN
# 38                    Olympiastadion, Berlin (GER)  '+0.9
# 39                    Olympiastadion, Berlin (GER)  '-0.3
# 40          Estádio Olímpico, Rio de Janeiro (BRA)    NaN
# 41                                     Reims (FRA)    NaN
# 42                        Letzigrund, Zürich (SUI)    NaN
# 43                  Neckarstadion, Stuttgart (GER)    NaN
# 44                                      Nomi (JPN)    NaN

# %%
women_outdoor
# Out:
#                   Competitor Country                 Date  \
# 0          Agnes Jebet TIROP     KEN  2021-09-12 00:00:00
# 1           Anita WŁODARCZYK     POL  2016-08-28 00:00:00
# 1           NaN            Stadion PGE Narodowy, Warszawa (POL)    NaN
# 2           NaN                              Columbia, MO (USA)    NaN
# 3           NaN       Gottlieb-Daimler Stadion, Stuttgart (GER)    NaN
# 4           NaN                    Stade Louis II, Monaco (MON)    NaN
# 5           NaN                               Chicago, IL (USA)    NaN
# 6           NaN                       Dorena Lake, Oregon (USA)    NaN
# 7           NaN                                 Barcelona (ESP)    NaN
# 8           NaN                                  Gqeberha (RSA)    NaN
# 9           NaN                          Indianapolis, IN (USA)    0.0
# 10          NaN            Olympic Stadium, Jamsil, Seoul (KOR)  '+1.3
# 11          NaN               Sports Park Mladost, Zagreb (CRO)    NaN
# 12          NaN                            Neubrandenburg (GDR)    NaN
# 13          NaN                                 Leningrad (URS)  '+1.4
# 14          NaN                    Stade Louis II, Monaco (MON)    NaN
# 15          NaN                                 Huangshan (CHN)    NaN
# 16          NaN                            Port Elizabeth (RSA)    NaN
# 17          NaN            Olympic Stadium, Jamsil, Seoul (KOR)    NaN
# 18          NaN                                   München (GER)    NaN
# 19          NaN                                 Huangshan (CHN)    NaN
# 20          NaN                                   Beijing (CHN)    NaN
# 21          NaN                                    Genève (SUI)    NaN
# 22          NaN            Blankers-Koen Stadion, Hengelo (NED)    NaN
# 23          NaN  Estadio de Atletismo del Turia, Valencia (ESP)    NaN
# 24          NaN                                  Valencia (ESP)    NaN
# 25          NaN                   Bruce Stadium, Canberra (AUS)    NaN
# 26          NaN                                    London (GBR)    NaN
# 27          NaN                               Seattle, WA (USA)    NaN
# 28          NaN                                    Moskva (URS)    NaN
# 29          NaN    Jesuit High School Track, Portland, OR (USA)    NaN
# 30          NaN                                  Brisbane (AUS)    NaN
# 31          NaN                                    Gdynia (POL)    NaN
# 32          NaN                                   Beijing (CHN)    NaN
# 33          NaN                            Herzogenaurach (GER)    NaN
# 34          NaN               Boudewijnstadion, Bruxelles (BEL)    NaN
# 35          NaN                    Stade Louis II, Monaco (MON)    NaN
# 36          NaN            Olympic Stadium, Jamsil, Seoul (KOR)    NaN
# 37          NaN                                    Moskva (URS)    NaN
# 38          NaN                     Stadio Olimpico, Roma (ITA)    NaN
# 39          NaN                                 Bruxelles (BEL)    NaN
# 40          NaN                 Hayward Field, Eugene, OR (USA)    NaN
# 41          NaN                 Hayward Field, Eugene, OR (USA)  '+0.9
# 42          NaN                               Lake Saroma (JPN)    NaN
# 43          NaN                   Olympic Stadium, London (GBR)    NaN
# 44          NaN      The Track at New Balance, Boston, MA (USA)    NaN
# 45          NaN               T. Robinson Stadium, Nassau (BAH)    NaN
# 46          NaN                          Philadelphia, PA (USA)    NaN
# 47          NaN                                 Castellón (ESP)    NaN
# 48          NaN                        Letzigrund, Zürich (SUI)    NaN
# 49          NaN                      Štark Arena, Beograd (SRB)    NWI

# %%
def clean_data(filename):
    if filename == 'Men 100m.csv':
        df = pd.read_csv(os.path.join(path, filename))[['Mark', 'Date']]
        df = df.rename(columns={'Mark':'Time'})
    elif filename == 'Men indoor.csv' or filename == 'Women indoor.csv' or filename == 'Women outdoor.csv' or filename == 'Men outdoor.csv':
        df = pd.read_csv(os.path.join(path, filename))[['Perf', 'Date']]
        df = df.rename(columns={'Perf':'Time'})
    else:
        df = pd.read_csv(os.path.join(path, filename))[['Date', 'Time']]
        
    df.dropna(subset=['Time'], axis=0, how='all', inplace=True)
    
    if filename in ('Men 10km.csv', 'Women 10km.csv', 'Men marathon.csv', 'Women marathon.csv', 'Men indoor.csv','Women indoor.csv','Women outdoor.csv','Men outdoor.csv'):
        df['Time'] = df['Time'].str.extract(r'^(\d{1,2}.\d{2}.\d{0,2})', expand=False)
    else:
        df['Time'] = df['Time'].str.extract(r'^(\d{1,2}.\d{1,4})', expand=False)
    
    '''if filename in ('Men marathon.csv', 'Women marathon.csv', 'Men 400m.csv', 'Women 100m.csv', 'Women 400m.csv'):
        df['Date'] = df['Date'].str.extract(r'^(\w{3,9}\s\d{1,22},\d{4})', expand=False)
        print(df.head())
        #df['Date'] = pd.to_datetime(df['Date'])
    else:
        df['Date'] = pd.to_datetime(df['Date'])
    
    #df = df.sort_values(by='Date')
    '''
    return df

# %%
def clean_data2(filename):
    if filename == 'Men 100m.csv':
        df = pd.read_csv(os.path.join(path, filename))[['Mark', 'Date']]
        df = df.rename(columns={'Mark':'Time'})
    elif filename == 'Men indoor.csv' or filename == 'Women indoor.csv' or filename == 'Women outdoor.csv' or filename == 'Men outdoor.csv':
        df = pd.read_csv(os.path.join(path, filename))[['Perf', 'Date']]
        df = df.rename(columns={'Perf':'Time'})
    else:
        df = pd.read_csv(os.path.join(path, filename))[['Date', 'Time']]
        
    df.dropna(subset=['Time'], axis=0, how='all', inplace=True)
    
    if filename in ('Men 10km.csv', 'Women 10km.csv', 'Men marathon.csv', 'Women marathon.csv'):
        df['Time'] = df['Time'].str.extract(r'^(\d{1,2}.\d{2}.\d{0,2})', expand=False)
    else:
        df['Time'] = df['Time'].str.extract(r'^(\d{1,2}.\d{1,4})', expand=False)
    
    '''if filename in ('Men marathon.csv', 'Women marathon.csv', 'Men 400m.csv', 'Women 100m.csv', 'Women 400m.csv'):
        df['Date'] = df['Date'].str.extract(r'^(\w{3,9}\s\d{1,22},\d{4})', expand=False)
        print(df.head())
        #df['Date'] = pd.to_datetime(df['Date'])
    else:
        df['Date'] = pd.to_datetime(df['Date'])
    
    #df = df.sort_values(by='Date')
    '''
    return df

# %%
men_marathon = clean_data('Men marathon.csv')
men10km = clean_data('Men 10km.csv')
men100m = clean_data('Men 100m.csv')
men400m = clean_data('Men 400m.csv')

women_marathon = clean_data('Women marathon.csv')
women10km = clean_data('Women 10km.csv')
women100m = clean_data('Women 100m.csv')
women400m = clean_data('Women 400m.csv')

men_indoor = clean_data('Men indoor.csv')
women_indoor = clean_data('Women indoor.csv')
men_outdoor = clean_data('Men outdoor.csv')
women_outdoor = clean_data('Women outdoor.csv')

men_outdoor_sh = clean_data2('Men outdoor.csv')
women_outdoor_sh = clean_data2('Women outdoor.csv')

# %%
men_outdoor
# Out:
#         Time                 Date
# 0        NaN  2012-09-07 00:00:00
# 1        NaN  2022-07-24 00:00:00
# 2      6.22   2023-02-25 00:00:00
# 3        NaN  2021-12-31 00:00:00
# 0  1960-06-21 00:00:00  10.0
# 1  2007-09-09 00:00:00  9.74
# 2  2006-06-11 00:00:00  9.77
# 3  2005-06-14 00:00:00  9.77
# 4  2006-08-18 00:00:00  9.77

# %% [markdown]
# * 400m

# %%
women400m.head()[cols]
# Out:
#                    Date   Time
# 0         9 May 1976[1]  49.77
# 1  18 September 1969[1]   51.7
# 2       22 June 1974[1]   49.9
# 3       22 June 1976[1]  49.75
# 4       29 July 1976[1]  49.29

# %%
men400m.head()[cols]
# Out:
#                  Date   Time
# 0     May 25, 1963[1]   44.9
# 1    June 19, 1936[1]   46.1
# 2   March 26, 1932[1]   46.4
# 3   August 5, 1932[1]   46.2
# 4  August 17, 1988[1]  43.29

# %% [markdown]
# -------

# %%
def minutes(time_string):
    m,s = time_string.split(':')
    return round((60*int(m)+float(s))/60,2)

def minutes2(time_string):
    h,m,s = time_string.split(':')
    return round((int(h)*3600+60*int(m)+float(s))/60,2)

women_marathon['Time'][39] = '5:40:00'

# %%
for x in [men10km,women10km]:
    for i in range(len(x['Time'])):
        x['Time'][i] = seconds(str(x['Time'][i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11952/3587891728.py in <module>
#       1 for x in [men10km,women10km]:
#       2     for i in range(len(x['Time'])):
# ----> 3         x['Time'][i] = seconds(str(x['Time'][i]))
#
# NameError: name 'seconds' is not defined

# %%
for x in [men_marathon,women_marathon]:
    for i in range(len(x['Time'])):
        x['Time'][i] = seconds2(str(x['Time'][i]))

# %%
men_outdoor['Time'][12]
# Out:
# nan

# %% [markdown]
# ### BEST

# %%
best_men_marathon = float(min(men_marathon['Time']))
best_men10km = float(min(men10km['Time']))
best_men100m = float(min(men100m['Time']))
best_men400m = float(min(men400m['Time']))

best_women_marathon = float(min(women_marathon['Time']))
best_women10km = float(min(women10km['Time']))
best_women100m = float(min(women100m['Time']))
best_women400m = float(min(women400m['Time']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11952/1625751449.py in <module>
# ----> 1 best_men_marathon = float(min(men_marathon['Time']))
#       2 best_men10km = float(min(men10km['Time']))
#       3 best_men100m = float(min(men100m['Time']))
#       4 best_men400m = float(min(men400m['Time']))
#       5
#
# ValueError: could not convert string to float: '2:01:09'

# %%
best_men = np.array([best_men100m,best_men400m,best_men10km,best_men_marathon])
best_women = np.array([best_women100m,best_women400m,best_women10km,best_women_marathon])
distance = [100,300,10**3,15*100]
plt.plot(distance, best_men, color='hotpink',label='Prędkości mężczyzn')
plt.plot(distance, best_women, color='purple',label='Prędkości kobiet')
plt.scatter(distance, best_men, color='skyblue',marker='*')
plt.scatter(distance, best_women, color='skyblue',marker='*')
plt.xticks(distance, ['100m','400m','10km','maraton'],rotation=90)
plt.legend()
plt.title('Czas na poszczególnych dystansach')
plt.savefig('Czas_na_dys')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11952/4139155019.py in <module>
# ----> 1 best_men = np.array([best_men100m,best_men400m,best_men10km,best_men_marathon])
#       2 best_women = np.array([best_women100m,best_women400m,best_women10km,best_women_marathon])
#       3 distance = [100,300,10**3,15*100]
#       4 plt.plot(distance, best_men, color='hotpink',label='Prędkości mężczyzn')
#       5 plt.plot(distance, best_women, color='purple',label='Prędkości kobiet')
#
# NameError: name 'best_men100m' is not defined

# %%
best_men = np.array([best_men100m,best_men400m])
best_women = np.array([best_women100m,best_women400m])
distance = [100,1100]
plt.plot(distance, best_men, color='hotpink',label='Prędkości mężczyzn')
plt.plot(distance, best_women, color='purple',label='Prędkości kobiet')
plt.scatter(distance, best_men, color='skyblue',marker='*')
plt.scatter(distance, best_women, color='skyblue',marker='*')
plt.xticks(distance, ['100m','400m'],rotation=90)
plt.legend()
plt.title('Czas na dystansach 100m i 400m')
plt.savefig('Czas_na_dys_100_400')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11952/828526122.py in <module>
# ----> 1 best_men = np.array([best_men100m,best_men400m])
#       2 best_women = np.array([best_women100m,best_women400m])
#       3 distance = [100,1100]
#       4 plt.plot(distance, best_men, color='hotpink',label='Prędkości mężczyzn')
#       5 plt.plot(distance, best_women, color='purple',label='Prędkości kobiet')
#
# NameError: name 'best_men100m' is not defined

# %%
best_men = np.array([best_men100m,best_men400m,best_men10km,best_men_marathon])
best_women = np.array([best_women100m,best_women400m,best_women10km,best_women_marathon])
distance = [100,1100,10**4,42.194*10**3]
tempo_men = [100/float(best_men100m),400/float(best_men400m),10**4/float(best_men10km),(42.194*10**3)/float(best_men_marathon)]
tempo_women = [100/float(best_women100m),400/float(best_women400m),10**4/float(best_women10km),(42.194*10**3)/float(best_women_marathon)]
plt.plot(distance, tempo_men, color='hotpink', label='Prędkości mężczyzn')
plt.plot(distance, tempo_women, color='purple',label='Prędkości kobiet')
plt.scatter(distance, tempo_men, color='skyblue', marker='*')
plt.scatter(distance, tempo_women, color='skyblue', marker='*')
plt.xticks(distance, ['100m','400m','10km','maraton'],rotation=90)
plt.legend()
plt.title('Prędkości na poszczególnych dystansach')
plt.savefig('Pred_na_dys')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11952/2247916229.py in <module>
# ----> 1 best_men = np.array([best_men100m,best_men400m,best_men10km,best_men_marathon])
#       2 best_women = np.array([best_women100m,best_women400m,best_women10km,best_women_marathon])
#       3 distance = [100,1100,10**4,42.194*10**3]
#       4 tempo_men = [100/float(best_men100m),400/float(best_men400m),10**4/float(best_men10km),(42.194*10**3)/float(best_men_marathon)]
#       5 tempo_women = [100/float(best_women100m),400/float(best_women400m),10**4/float(best_women10km),(42.194*10**3)/float(best_women_marathon)]
#
# NameError: name 'best_men100m' is not defined

# %% [markdown]
# __________

# %%
from datetime import datetime
best_men = ['0:9.58','0:19.19','0:43.03','1:40.91','2:11.96','3:26.00','3:43.13','4:44.79','7:20.61','12:49.00','26:11.00','57:31.00','2:01:09','2:38:43','6:09:14']
best_women = ['0:10.49','0:21.34','0:47.60','1:53.28','2:28.98','3:50.07','3:50.07','5:21.56','8:06.11','14:19.00','30:01.00','1:02:52.00','2:14:04','2:59:54','6:33:11']

distance_real = [100,200,400,800,10**3,15*100,1.6*10**3,2*10**3,3*10**3,5*10**3,10**4,21.0975*10**3,42.195*10**3,50*10**3,10**5]
distance = [1*i for i in range(len(best_men))]

# %%
best_men = list(map(minutes,best_men[:-3])) + list(map(minutes2,best_men[-3:]))
best_women = list(map(minutes,best_women[:-4])) + list(map(minutes2,best_women[-4:]))

# %%
#plt.plot(distance, best_men, color='hotpink',label='Prędkości mężczyzn')
#plt.plot(distance, best_women, color='purple',label='Prędkości kobiet')
plt.scatter(distance, best_men, color='skyblue',marker=u'$\u2642$',label='Czasy mężczyzn',s=200)
plt.scatter(distance, best_women, color='hotpink',marker=u'$\u2640$',label='Czasy kobiet',s=200)
plt.xticks(distance, ['100m','200m','400m','800m','1km','1.5km','mila','2km','3km','5km','10km','półmaraton','maraton','50km','100km'],rotation=30)
plt.legend()
plt.xlabel('dystans',fontsize=14,fontweight='bold')
plt.ylabel('czas [min]',fontsize=14,fontweight='bold')
plt.title('Czas na poszczególnych dystansach',fontweight='bold',fontsize=18)
plt.savefig('Czas_na_dys.PNG')
plt.show()

# %%
tempo_men = [distance_real[i]/best_men[i] for i in range(len(best_men))]
tempo_women = [distance_real[i]/best_women[i] for i in range(len(best_men))]
plt.scatter(distance, tempo_women, color='hotpink',marker=u'$\u2640$',label='Tempo kobiet',s=200)
plt.scatter(distance, tempo_men, color='skyblue',marker=u'$\u2642$',label='Tempo mężczyzn',s=200)
plt.xticks(distance, ['100m','200m','400m','800m','1km','1.5km','mila','2km','3km','5km','10km','półmaraton','maraton','50km','100km'],rotation=30)
plt.xlabel('dystans',fontsize=14,fontweight='bold')
plt.ylabel(r'tempo $\left[\frac{[min]}{[km]}\right]$',fontsize=14,fontweight='bold')
plt.legend()
plt.title('Tempo na poszczególnych dystansach',fontweight='bold',fontsize=18)
plt.savefig('Pred_na_dys.PNG')
plt.show()

# %%
from scipy.optimize import curve_fit
f = lambda x,a,b: np.exp(a*x+b)
fit = curve_fit(f,distance,best_men)
fit2 = curve_fit(f,distance,best_women)
a_men, b_men = fit[0]
a_women, b_women = fit2[0]
plt.scatter(distance, best_men, color='skyblue',marker=u'$\u2642$',label='Prędkości mężczyzn',s=200)
plt.scatter(distance, best_women, color='hotpink',marker=u'$\u2640$',label='Prędkości kobiet',s=200)
plt.plot(distance,[f(i,a_men,b_men) for i in distance], color='#33AAF9')
plt.plot(distance,[f(i,a_women,b_women) for i in distance],color='#FF00FF')
plt.xticks(distance, ['100m','200m','400m','800m','1km','1.5km','mila','2km','3km','5km','10km','półmaraton','maraton','50km','100km'],rotation=30)
plt.legend()
plt.xlabel('dystans',fontsize=14,fontweight='bold')
plt.ylabel('czas [min]',fontsize=14,fontweight='bold')
plt.title('Czas na poszczególnych dystansach',fontweight='bold',fontsize=18)
plt.savefig('time_fit.PNG')
plt.show()

# %%
plt.scatter(distance, [best_men[i]/best_women[i] for i in range(len(best_men))], color='#9933FF',s=130)
plt.xticks(distance, ['100m','200m','400m','800m','1km','1.5km','mila','2km','3km','5km','10km','półmaraton','maraton','50km','100km'],rotation=30)
plt.xlabel('dystans',fontsize=14)
plt.ylabel(r'$\frac{czas \ mężczyzn}{czas \ kobiet}[min]$',fontsize=14,fontweight='bold')
plt.title('Stosunek czasu mężczyzn do czasu kobiet na poszczególnych dystansach',fontweight='bold',fontsize=18)
plt.savefig('menwomen.PNG')
plt.show()

# %%
0.16/0.1
# Out:
# 1.5999999999999999

# %%
9.58/60
# Out:
# 0.15966666666666668
